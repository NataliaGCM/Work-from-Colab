# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaGCM/Work-from-Colab/blob/main/%D0%9F%D0%B0%D1%80%D1%81%D0%B5%D1%80_%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Библиотеки

# %%
import os
import requests
import pandas as pd
from googleapiclient.discovery import build
from IPython.display import display, Image

# %% [markdown]
# Основной код парсера

# %%
API_KEY = "AIzaSyCC8BgOZrnEGt_-XL5XNDvEqYzoB7-5SkA"
CX = "075f71a79d203470b"

query = "рентген легких"
num_images = 20

service = build("customsearch", "v1", developerKey=API_KEY)

def google_image_search(query, num_results):
    image_urls = []
    start_index = 1
    while len(image_urls) < num_results:
        num = min(10, num_results - len(image_urls))
        res = service.cse().list(
            q=query,
            cx=CX,
            searchType='image',
            num=num,
            start=start_index
        ).execute()

        for item in res.get('items', []):
            image_urls.append({
                'title': item.get('title'),
                'link': item.get('link'),
                'mime': item.get('mime'),
                'width': item.get('image', {}).get('width'),
                'height': item.get('image', {}).get('height')
            })
        start_index += num
    return image_urls

print("Ищем изображения...")
images = google_image_search(query, num_images)

df = pd.DataFrame(images)
display(df)

df.to_csv("images_info.csv", index=False, encoding='utf-8')
print("Информация об изображениях сохранена в images_info.csv")

images_dir = "downloaded_images"
os.makedirs(images_dir, exist_ok=True)

def download_image(url, path):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        with open(path, 'wb') as f:
            f.write(response.content)
        print(f"Скачано: {path}")
    except Exception as e:
        print(f"Ошибка при скачивании {url}: {e}")

print("Скачиваем изображения...")
for idx, row in df.iterrows():
    image_url = row['link']


    file_extension = os.path.splitext(image_url)[1]
    if not file_extension.lower() in [".jpg", ".jpeg", ".png", ".gif", ".bmp"]:
        file_extension = ".jpg"
    file_name = f"image_{idx+1}{file_extension}"
    file_path = os.path.join(images_dir, file_name)
    download_image(image_url, file_path)

print("Скачивание завершено.")
# Out:
# Ищем изображения...
#                                                 title  \
# 0   Рентген легких или флюорограмма. В чем разница...
# 1   File:Chest Xray PA 3-8-2010.png - Wikimedia Co...
# 2   Рентген грудной клетки в СПб - цена 1600 руб |...
# 3               Рентген легких в Одинцово - Альтамед+
# 4   Рентген грудной клетки с определением кардио-т...
# 5              Рентген легких отличия от флюорографии
# 6   Рентген грудной клетки в СПб - цена 1600 руб |...
# 7   8,642 Рентген Легких Stock Vectors and Vector ...
# 8   Рентген легких Хмельницкий Ультрадиагностика з...
# 9   Рентген грудной клетки: что показывает, как пр...
# 10          Рентген легких пройти в МЦ Норма в Муроме
# 11  Что ожидать после диагностирования узелка легкого
# 12  КТ или рентген легких: что лучше? - блог клини...
# 13  Рентген - доступный метод диагностики - Статьи...
# 14  Диагностический центр "SISTEM" | ✓ЦИФРОВОЙ РЕН...
# 15  Рентген легких здорового человека и зараженног...
# 16                                     Рентген лёгких
# 17  НОВОСТИ СОЧИ | Рентген легких здорового челове...
# 18          Рентген легких - показания к исследованию
# 19  Рентген легких в Москве, цены на платную рентг...
#
#                                                  link        mime  width  \
# 0   https://domedica24.ru/wp-content/uploads/2023/...  image/jpeg   1024
# 1   https://upload.wikimedia.org/wikipedia/commons...   image/png   2412
# 2   https://domedica24.ru/wp-content/uploads/2023/...  image/jpeg   2707
# 3   https://www.altamedplus.ru/upload/delight.webp...  image/webp    691
# 4   https://domedica24.ru/wp-content/uploads/2023/...  image/jpeg   2768
# 5   https://static.tildacdn.com/tild3035-6466-4465...  image/jpeg   1024
# 6   https://domedica24.ru/wp-content/uploads/2023/...  image/jpeg   1808
# 7   https://www.shutterstock.com/image-vector/hume...  image/jpeg    260
# 8   https://mrt-ct.com.ua/images/renthen/renthen-l...  image/jpeg   1920
# 9   https://www.fdoctor.ru/upload/iblock/501/rentg...  image/jpeg    410
# 10  https://norma33.ru/pics/catalogtop/dd/1451_Ima...   image/png    520
# 11  https://ru.rockymountaincancercenters.com/hubf...  image/jpeg   1000
# 12  https://domedica24.ru/wp-content/uploads/2023/...  image/jpeg   2387
# 13  https://terve24.ru/media/public/articles/6e6de...  image/jpeg    824
# 14  https://lookaside.instagram.com/seo/google_wid...      image/   1080
# 15  https://lookaside.fbsbx.com/lookaside/crawler/...      image/    584
# 16  https://viterramed.ru/upload/iblock/4c3/4c3752...  image/jpeg    350
# 17  https://lookaside.instagram.com/seo/google_wid...      image/    584
# 18           https://mrt-vmsk.ru/images/988879004.jpg  image/jpeg    480
# 19  https://www.medicina.ru/upload/iblock/0f4/u001...  image/webp    600
#
#     height
# 0     1004
# 1     1956
# 2     2654
# 3      389
# 4     2766
# 5      856
# 6     1872
# 7      280
# 8     1080
# 9      336
# 10     423
# 11     667
# 12    2398
# 13     509
# 14    1080
# 15     494
# 16     350
# 17     494
# 18     320
# 19     494
# Информация об изображениях сохранена в images_info.csv
# Скачиваем изображения...
# Скачано: downloaded_images/image_1.jpg
# Ошибка при скачивании https://upload.wikimedia.org/wikipedia/commons/c/c8/Chest_Xray_PA_3-8-2010.png: 403 Client Error: Forbidden. Please comply with the User-Agent policy: https://meta.wikimedia.org/wiki/User-Agent_policy for url: https://upload.wikimedia.org/wikipedia/commons/c/c8/Chest_Xray_PA_3-8-2010.png
# Скачано: downloaded_images/image_3.jpg
# Скачано: downloaded_images/image_4.jpg
# Скачано: downloaded_images/image_5.jpg
# Скачано: downloaded_images/image_6.jpg
# Скачано: downloaded_images/image_7.jpg
# Скачано: downloaded_images/image_8.jpg
# Скачано: downloaded_images/image_9.jpg
# Скачано: downloaded_images/image_10.jpg
# Скачано: downloaded_images/image_11.png
# Скачано: downloaded_images/image_12.jpeg
# Скачано: downloaded_images/image_13.jpg
# Скачано: downloaded_images/image_14.jpeg
# Скачано: downloaded_images/image_15.jpg
# Скачано: downloaded_images/image_16.jpg
# Скачано: downloaded_images/image_17.jpg
# Скачано: downloaded_images/image_18.jpg
# Скачано: downloaded_images/image_19.jpg
# Ошибка при скачивании https://www.medicina.ru/upload/iblock/0f4/u001fjd7gadae91eew9bfiz6wnvfn0rj/1.webp: HTTPSConnectionPool(host='www.medicina.ru', port=443): Max retries exceeded with url: /upload/iblock/0f4/u001fjd7gadae91eew9bfiz6wnvfn0rj/1.webp (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Скачивание завершено.
